# %%
import pandas as pd

df = pd.read_excel(r"2019-XTern- Work Sample Assessment Data Science-DS.xlsx")
print(df)
# Out:
#        scooter_id  xcoordinate  ycoordinate  power_level  dist_from_bus  \
# 0             0.0     0.906835     0.776484          0.0      27.362841
# 1             1.0     0.928587     0.804964          2.0      27.327306
# 2             2.0     0.904091     0.784043          1.0      27.359412
# 3             3.0     0.906752     0.804461          0.0      27.343057
# 4             4.0     0.900641     0.781683          4.0      27.363518
# 5             5.0     0.899680     0.790893          2.0      27.357664
# 6             6.0     0.873765     0.808707          4.0      27.363323
# 7             7.0     0.913476     0.789742          5.0      27.348755
# 8             8.0     0.915256     0.790685          4.0      27.346831
# 9             9.0     0.916273     0.785860          5.0      27.349537
# 10           10.0     0.906847     0.805807          0.0      27.342036
# 11           11.0     0.905919     0.811344          3.0      27.338765
# ...

# %%
print("notes.txt")
# Out:
# notes.txt
